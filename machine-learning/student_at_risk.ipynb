# %% [markdown]
# <a href="https://colab.research.google.com/github/MUHIYADIN2025/Schholarship_Project/blob/main/machine-learning/student_at_risk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DAY ONE - AI FOUNDATIONS AND SETUP

# %% [markdown]
# ## loading and reviewing data

# %%
import pandas as pd

# %%
df= pd.read_csv("student-por.csv",sep=";")

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (649, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %% [markdown]
# # Day 2 EDA

# %%
new_df = df.copy()

# %%
new_df.isnull().sum()

# isn()
new_df.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
# drop()
new_df.drop(columns=["school"])
new_df


# drop index
new_df.drop(index=0)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
# dropna()
new_df.dropna()

# subset
new_df.dropna(subset=["school"])
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
# filnna()
new_df["school"].mode()
# Out:
# 0    GP
# Name: school, dtype: object

# %%
new_df["school"]=new_df["school"].fillna(new_df["school"].mode()[0])

# %%
# numerical
new_df["age"].median()
# Out:
# 17.0

# %%
new_df["age"].fillna(new_df["age"].median()).astype(int)
# Out:
# 0      18
# 1      17
# 2      15
# 3      15
# 4      16
#        ..
# 644    19
# 645    18
# 646    18
# 647    17
# 648    18
# Name: age, Length: 649, dtype: int64

# %%
# dupliactes
# False, first,last
new_df[new_df.duplicated(keep="last")]
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, higher, internet, romantic, famrel, freetime, goout, Dalc, Walc, health, absences, G1, G2, G3]
# Index: []
#
# [0 rows x 33 columns]

# %%
new_df=new_df.drop_duplicates()

# %%
new_df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
new_df["at_risk"]=(new_df["G3"]<10).astype(int)

# %%
new_df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3 at_risk
# 0        3     4     1     1       3        4   0  11  11       0
# 1        3     3     1     1       3        2   9  11  11       0
# 2        3     2     2     3       3        6  12  13  12       0
# 3        2     2     1     1       5        0  14  14  14       0
# 4        3     2     1     2       5        0  11  13  13       0
#
# [5 rows x 34 columns]

# %%
features = [
    "studytime", "failures", "schoolsup", "famsup", "activities",
    "higher", "internet", "famrel", "health", "absences"
]

X=new_df[features].copy()

# %%
X
# Out:
#      studytime  failures schoolsup famsup activities higher internet  famrel  \
# 0            2         0       yes     no         no    yes       no       4
# 1            2         0        no    yes         no    yes      yes       5
# 2            2         0       yes     no         no    yes      yes       4
# 3            3         0        no    yes        yes    yes      yes       3
# 4            2         0        no    yes         no    yes       no       4
# ..         ...       ...       ...    ...        ...    ...      ...     ...
# 644          3         1        no     no        yes    yes      yes       5
# 645          2         0        no    yes         no    yes      yes       4
# 646          2         0        no     no        yes    yes       no       1
# 647          1         0        no     no         no    yes      yes       2
# 648          1         0        no     no         no    yes      yes       4
#
#      health  absences
# ...

# %%
Y=new_df["at_risk"]

# %%
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 644    0
# 645    0
# 646    1
# 647    0
# 648    0
# Name: at_risk, Length: 649, dtype: int64

# %%
class_balance= Y.value_counts()

# %%
class_balance
# Out:
# at_risk
# 0    549
# 1    100
# Name: count, dtype: int64

# %%
model_data=X.copy()

# %%
model_data["at_risk"]=Y

# %%
model_data.head()
# Out:
#    studytime  failures schoolsup famsup activities higher internet  famrel  \
# 0          2         0       yes     no         no    yes       no       4
# 1          2         0        no    yes         no    yes      yes       5
# 2          2         0       yes     no         no    yes      yes       4
# 3          3         0        no    yes        yes    yes      yes       3
# 4          2         0        no    yes         no    yes       no       4
#
#    health  absences  at_risk
# 0       3         4        0
# 1       3         2        0
# 2       3         6        0
# 3       5         0        0
# 4       5         0        0

# %%
model_data.to_csv(
    "student-cleaned-data.csv",
    index=False
)

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
from sklearn.tree import DecisionTreeClassifier

# %%
X = model_data.drop(columns=['at_risk'])  # Beddel 'grade' haddii uu target-kaaga yahay column kale
y = 'at_risk'

# %%
X
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 644    0
# 645    0
# 646    1
# 647    0
# 648    0
# Name: at_risk, Length: 649, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

# %%
# preprocessng

numeric_features = [
    "studytime",
    "failures",
    "famrel",
    "health",
    "absences"
]

categorical_features = [
    "schoolsup",
    "famsup",
    "activities",
    "higher",
    "internet"
]

preprocessor = ColumnTransformer([
    ("num", StandardScaler(), numeric_features),
    ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features)
])

# %%
dt_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('model', DecisionTreeClassifier(random_state=42))
])

# %%
dt_pipeline.fit(X_train, Y_train)
Y_pred = dt_pipeline.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(Y_test, Y_pred)
precision = precision_score(Y_test, Y_pred)
recall = recall_score(Y_test, Y_pred)
f1 = f1_score(Y_test, Y_pred)

print("Accuracy :", accuracy)
print("Precision:", precision)
print("Recall   :", recall)
print("F1 Score :", f1)
# Out:
# Accuracy : 0.8307692307692308
# Precision: 0.3333333333333333
# Recall   : 0.4666666666666667
# F1 Score : 0.3888888888888889

# %%
from google.colab import drive
import pickle

drive.mount('/content/drive')

with open('/content/drive/MyDrive/student_at_risk_decision_tree.pkl', 'wb') as file:
    pickle.dump(dt_pipeline, file)
# Out:
# Mounted at /content/drive

# %%
import os

if os.path.exists('/content/drive'):
    print("Google Drive is mounted.")
else:
    print("Google Drive is NOT mounted.")
# Out:
# Google Drive is NOT mounted.
